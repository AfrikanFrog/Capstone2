# %%
#import packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in data
df=pd.read_csv ('../data/processed/vehicles-v1.csv')

# %%
#familiarize
df.head()
# Out:
#                    region  price  year manufacturer model condition cylinders  \
# 0                prescott   6000   NaN          NaN   NaN       NaN       NaN
# 1            fayetteville  11900   NaN          NaN   NaN       NaN       NaN
# 2            florida keys  21000   NaN          NaN   NaN       NaN       NaN
# 3  worcester / central MA   1500   NaN          NaN   NaN       NaN       NaN
# 4              greensboro   4900   NaN          NaN   NaN       NaN       NaN
#
#   fuel  odometer title_status transmission drive size type paint_color state
# 0  NaN       NaN          NaN          NaN   NaN  NaN  NaN         NaN    az
# 1  NaN       NaN          NaN          NaN   NaN  NaN  NaN         NaN    ar
# 2  NaN       NaN          NaN          NaN   NaN  NaN  NaN         NaN    fl
# 3  NaN       NaN          NaN          NaN   NaN  NaN  NaN         NaN    ma
# 4  NaN       NaN          NaN          NaN   NaN  NaN  NaN         NaN    nc

# %%
df.shape
# Out:
# (426880, 16)

# %%
df.columns
# Out:
# Index(['region', 'price', 'year', 'manufacturer', 'model', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission',
#        'drive', 'size', 'type', 'paint_color', 'state'],
#       dtype='object')

# %%
df.sample(50)
# Out:
#                          region  price    year   manufacturer  \
# 57356           san luis obispo  16000  2008.0           ford
# 150746               fort wayne   9500  2010.0            bmw
# 237862               greensboro  33590  2019.0            ram
# 236067             fayetteville  34900  2012.0            ram
# 274932            new york city    359  2019.0            bmw
# 297860                 columbus  10950  2015.0           jeep
# 138115  spokane / coeur d'alene  11995  2016.0            kia
# 54198                sacramento  37990  2017.0  mercedes-benz
# 322003                 portland  42995  2014.0         toyota
# 422348                milwaukee   9977  2012.0           ford
# 96483     ft myers / SW florida  14995  2010.0  mercedes-benz
# 65956                  stockton  10588  2012.0        hyundai
# 202287             grand rapids  25000  2015.0      chevrolet
# 172182                lexington  11984  2013.0       chrysler
# 34450               los angeles  27590  2020.0     volkswagen
# 270219            hudson valley  19950  2018.0          honda
# 150857               fort wayne     85  2016.0           ford
# 103576                    ocala   4000  2007.0         nissan
# 50821              reno / tahoe  19991  2018.0          mazda
# 45758              palm springs  29995  2014.0      chevrolet
# 240758    raleigh / durham / CH  23398  2011.0            bmw
# 41352             orange county   3000  1999.0           jeep
# 5602         anchorage / mat-su  20000  2016.0           mini
# 372116                  el paso   5995  2011.0     volkswagen
# 315377              east oregon   9995  2003.0           ford
# 89016            washington, DC   7499  2011.0         toyota
# 180174                    maine  32990  2019.0         nissan
# 251075               central NJ  38995  2007.0      chevrolet
# 73812          colorado springs  29990  2018.0  mercedes-benz
# 218763                 meridian      0  2010.0            gmc
# 82814             western slope  18900  2017.0      chevrolet
# 123546                  atlanta  52900  2015.0           ford
# 198102            detroit metro   4800  2012.0           ford
# 42045             orange county   1200  1993.0      chevrolet
# 119352           treasure coast  31990  2017.0            bmw
# 30214             inland empire  10995  2013.0         toyota
# 214371    minneapolis / st paul  10998  2012.0          honda
# 116060              tallahassee  46800  2015.0            gmc
# 14413                    tucson  33990  2020.0          lexus
# 258053             south jersey  22490  2018.0         subaru
# 285962              grand forks  18990  2015.0        hyundai
# 127813                   hawaii      0  2017.0      chevrolet
# 256660             south jersey  17995  2002.0           ford
# 292193                cleveland   1500  2004.0        hyundai
# 321301             oregon coast    232  2009.0           jeep
# 87036                 new haven  15950  2012.0            gmc
# 292889                cleveland  35000  2016.0            ram
# 183607                baltimore  14500  1963.0       chrysler
# 380223              san antonio   8995  2012.0      chevrolet
# 101909         north central FL      0  2015.0           ford
#
#                              model  condition    cylinders      fuel  \
# 57356                        f-250  excellent  8 cylinders    diesel
# 150746                 328i xdrive       good  6 cylinders       gas
# 237862      1500 quad cab big horn       good  6 cylinders       gas
# 236067                        3500  excellent  6 cylinders    diesel
# 274932                          x3        NaN          NaN       gas
# 297860                     compass  excellent  4 cylinders       gas
# 138115                    forte lx        NaN          NaN       gas
# 54198                 mercedes-amg       good          NaN     other
# 322003                      tundra        NaN  8 cylinders       gas
# 422348                       f-150        NaN  8 cylinders     other
# 96483                      m-class        NaN          NaN    diesel
# 65956                   sonata gls       good  4 cylinders       gas
# 202287              silverado 1500  excellent  8 cylinders       gas
# 172182                town country        NaN  6 cylinders       gas
# 34450         golf gti s hatchback       good          NaN       gas
# 270219                      accord        NaN          NaN       gas
# 150857             fusion titanium        NaN          NaN       gas
# 103576                    quest sl  excellent  6 cylinders       gas
# 50821                         cx-5        NaN          NaN       gas
# 45758   express commercial cutaway        NaN  8 cylinders     other
# 240758              m3 convertible   like new          NaN       gas
# 41352   grand cherokee limited 4x4       good  8 cylinders       gas
# 5602      cooper john cooper works  excellent          NaN       gas
# 372116                        golf       good  5 cylinders       gas
# 315377                     mustang  excellent  6 cylinders       gas
# 89016                        camry  excellent  4 cylinders       gas
# 180174                  pathfinder        NaN          NaN       gas
# 251075       corvette coupe 6.0l v        NaN          NaN       gas
# 73812                gla 250 sport       good          NaN     other
# 218763                    yukon xl        NaN  8 cylinders       NaN
# 82814                     traverse        NaN  6 cylinders       gas
# 123546        super duty f-350 drw  excellent  8 cylinders    diesel
# 198102                      escape  excellent  4 cylinders       gas
# 42045              caprice classic       good  8 cylinders       gas
# 119352      3 series 340i sedan 4d       good          NaN       gas
# 30214                    prius two       good  4 cylinders  electric
# 214371                   crosstour        NaN          NaN       gas
# 116060               sierra 2500hd   like new  8 cylinders    diesel
# 14413     ux 250h sport utility 4d       good          NaN     other
# 258053                   crosstrek        NaN          NaN       gas
# 285962            santa fe limited  excellent  6 cylinders       gas
# 127813                      impala        NaN          NaN       gas
# 256660     thunderbird convertible  excellent  6 cylinders       gas
# 292193                     elantra       good  4 cylinders       gas
# 321301                    wrangler  excellent  6 cylinders       gas
# 87036                       sierra        NaN          NaN       gas
# 292889                        5500       good  6 cylinders    diesel
# 183607            new yorker wagon       good          NaN       gas
# 380223                      impala        NaN          NaN     other
# 101909                       f-350        NaN          NaN    diesel
#
#         odometer title_status transmission drive       size         type  \
# 57356   185000.0        clean    automatic   4wd  full-size        truck
# 150746   99835.0        clean    automatic   NaN        NaN          NaN
# 237862   20672.0        clean        other   NaN        NaN       pickup
# 236067   85622.0        clean    automatic   4wd  full-size        truck
# 274932   28873.0        clean    automatic   NaN        NaN        other
# 297860   90299.0        clean    automatic   4wd        NaN          SUV
# 138115   62944.0        clean    automatic   fwd        NaN        sedan
# 54198    48893.0        clean        other   NaN        NaN        sedan
# 322003   69963.0        clean    automatic   4wd        NaN        truck
# 422348  106279.0        clean    automatic   NaN        NaN        truck
# 96483    86001.0        clean    automatic   NaN        NaN          SUV
# 65956    83488.0        clean    automatic   fwd        NaN        sedan
# 202287  121600.0         lien    automatic   4wd  full-size        truck
# 172182  147943.0        clean        other   fwd        NaN          van
# 34450     1309.0        clean        other   fwd        NaN        sedan
# 270219   84020.0        clean    automatic   fwd  full-size        sedan
# 150857  134000.0        clean    automatic   NaN        NaN          NaN
# 103576  147638.0        clean    automatic   fwd  full-size     mini-van
# 50821    77119.0        clean    automatic   fwd        NaN        wagon
# 45758   179362.0        clean    automatic   rwd        NaN        other
# 240758  117088.0        clean    automatic   NaN        NaN          NaN
# 41352   195000.0        clean    automatic   4wd        NaN          SUV
# 5602     48000.0        clean       manual   NaN        NaN          NaN
# 372116  120318.0        clean    automatic   fwd        NaN    hatchback
# 315377   30584.0        clean    automatic   rwd    compact  convertible
# 89016   134000.0        clean    automatic   fwd  full-size        sedan
# 180174   32260.0        clean    automatic   4wd        NaN        wagon
# 251075    1265.0        clean    automatic   rwd        NaN        coupe
# 73812    15458.0        clean        other   fwd        NaN        other
# 218763       0.0        clean    automatic   4wd        NaN          SUV
# 82814    91615.0        clean    automatic   4wd        NaN          SUV
# 123546  106000.0        clean    automatic   4wd  full-size        truck
# 198102  123000.0      rebuilt    automatic   4wd   mid-size          SUV
# 42045   143000.0        clean        other   rwd  full-size        sedan
# 119352   19366.0        clean    automatic   rwd        NaN        sedan
# 30214    87701.0        clean    automatic   fwd        NaN        other
# 214371  162375.0        clean    automatic   4wd        NaN    hatchback
# 116060  114785.0        clean    automatic   4wd  full-size        truck
# 14413     5329.0        clean        other   NaN        NaN    hatchback
# 258053   42450.0        clean    automatic   NaN        NaN          NaN
# 285962  154284.0        clean    automatic   4wd   mid-size          SUV
# 127813   14725.0        clean    automatic   fwd  full-size        sedan
# 256660   41911.0        clean    automatic   rwd   mid-size  convertible
# 292193   97000.0        clean    automatic   fwd    compact        sedan
# 321301  206037.0        clean       manual   4wd   mid-size          SUV
# 87036   151492.0        clean    automatic   4wd        NaN       pickup
# 292889  136172.0        clean    automatic   4wd        NaN          NaN
# 183607   22504.0        clean    automatic   NaN        NaN          NaN
# 380223  102971.0        clean    automatic   NaN  full-size        sedan
# 101909  126351.0        clean    automatic   4wd        NaN       pickup
#
#        paint_color state
# 57356          red    ca
# 150746        grey    in
# 237862       white    nc
# 236067       white    nc
# 274932       black    ny
# 297860       black    oh
# 138115       black    id
# 54198        black    ca
# 322003       white    or
# 422348         red    wi
# 96483          NaN    fl
# 65956          NaN    ca
# 202287        blue    mi
# 172182         NaN    ky
# 34450          red    ca
# 270219       black    ny
# 150857         NaN    in
# 103576       white    fl
# 50821         blue    ca
# 45758        white    ca
# 240758         NaN    nc
# 41352       silver    ca
# 5602         green    ak
# 372116        grey    tx
# 315377         red    or
# 89016         grey    dc
# 180174       white    me
# 251075         red    nj
# 73812        white    co
# 218763         NaN    ms
# 82814          red    co
# 123546       white    ga
# 198102        grey    mi
# 42045       custom    ca
# 119352         red    fl
# 30214       silver    ca
# 214371         NaN    mn
# 116060        blue    fl
# 14413          red    az
# 258053       white    nj
# 285962      silver    nd
# 127813       white    hi
# 256660       black    nj
# 292193       white    oh
# 321301      orange    or
# 87036          NaN    ct
# 292889       white    oh
# 183607         NaN    md
# 380223       black    tx
# 101909       brown    fl

# %%
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#uc as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([df.isnull().sum(),100 * df.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=False)
# Out:
#                count          %
# size          306361  71.767476
# cylinders     177678  41.622470
# condition     174104  40.785232
# drive         130567  30.586347
# paint_color   130203  30.501078
# type           92858  21.752717
# manufacturer   17646   4.133714
# title_status    8242   1.930753
# model           5277   1.236179
# odometer        4400   1.030735
# fuel            3013   0.705819
# transmission    2556   0.598763
# year            1205   0.282281
# region             0   0.000000
# price              0   0.000000
# state              0   0.000000
